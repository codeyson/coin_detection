# %%
import os
# !pip install ultralytics
#!yolo checks

# %%
from ultralytics import YOLO

# %%
# Set root directory to your local path
ROOT_DIR = "COIN_DETECTION"

# %%
# Load model
model_coin = YOLO("yolov8m.pt")

# %%
import os

ROOT_DIR = os.getcwd()
print("ROOT_DIR =", ROOT_DIR)
# Out:
# ROOT_DIR = c:\Users\Frederick Masangkay\projects\coin_detection

# %%
from ultralytics import settings
import os

ROOT_DIR = os.getcwd()

settings.update({'datasets_dir': ROOT_DIR})
print(settings)
# Out:
# JSONDict("C:\Users\Frederick Masangkay\AppData\Roaming\Ultralytics\settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "c:\\Users\\Frederick Masangkay\\projects\\coin_detection",
#   "weights_dir": "weights",
#   "runs_dir": "runs",
#   "uuid": "529878343a9123707bac7186e35d27d94f2c08722bdc74a343eb166c467f6463",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": false,
#   "wandb": false,
#   "vscode_msg": true,
#   "openvino_msg": true
# }

# %%
# Train model
results = model_coin.train(
    data=os.path.join(ROOT_DIR, "data/data.yaml"),
    epochs=1
)
# Out:
# Ultralytics 8.4.14  Python-3.12.9 torch-2.10.0+cpu CPU (12th Gen Intel Core i5-1235U)
# ...

# %%
# After training, load best weights
model = YOLO("runs/detect/train/weights/best.pt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # After training, load best weights
# ----> 2 model = YOLO("runs/detect/train/weights/best.pt")
#
# File c:\Users\Frederick Masangkay\anaconda3\envs\CPE311-Masangkay\Lib\site-packages\ultralytics\models\yolo\model.py:76, in YOLO.__init__(self, model, task, verbose)
#      73     self.__dict__ = new_instance.__dict__
#      74 else:
#      75     # Continue with default YOLO initialization
# ---> 76     super().__init__(model=model, task=task, verbose=verbose)
#      77     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      78         from ultralytics import RTDETR
#
# File c:\Users\Frederick Masangkay\anaconda3\envs\CPE311-Masangkay\Lib\site-packages\ultralytics\engine\model.py:144, in Model.__init__(self, model, task, verbose)
# ...

# %%
# Run inference on test images
results = model.predict(
    source=os.path.join(ROOT_DIR, "data/test/images"),
    conf=0.25,
    save=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-710575114.py in <cell line: 0>()
# ----> 1 results1 = model(source="/content/gdrive/MyDrive/coin_detection1/test/images", show=True, conf=0.25, save=True)
#
# NameError: name 'model' is not defined
